# %% [markdown]
# # 데이터 전처리
# ### BroadCating, Crew_group 데이터 병합 부분을 맡았습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.rc('font', family = 'AppleGothic')

# %% [markdown]
# ### 방송판매 데이터

# %%
df1 = pd.read_csv('Broadcasting.csv')

# %%
df1_list = list(df1.columns)

# %%
df1_list
# Out:
# ['방송Code',
#  '소요분',
#  '가중분',
#  '방송구분',
#  '프로그램명',
#  '상품ID',
#  '상품명',
#  '매입과세구분',
#  '상품목표취급금액',
#  '상품목표주문금액',
#  '상품목표공헌이익금액',
#  '판매단가',
#  '수수료율',
#  '상품주문수량',
#  '상품주문금액',
#  '상품취소수량',
#  '상품취소금액',
#  '상품순주문수량',
#  '상품순주문금액',
#  '상품예상취급금액',
#  'ARS금액',
#  '매입형태',
#  '배송방식',
#  '상품방송순번',
#  '방송시작시간',
#  '방송종료시간']

# %%
df1.iloc[:, :6].boxplot()
# Out:
# <AxesSubplot: >

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26283 entries, 0 to 26282
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   방송Code      26283 non-null  float64
#  1   소요분         26283 non-null  float64
#  2   가중분         26283 non-null  float64
#  3   방송구분        26283 non-null  object
#  4   프로그램명       26283 non-null  object
#  5   상품ID        26283 non-null  int64
#  6   상품명         26283 non-null  object
#  7   매입과세구분      26283 non-null  object
#  8   상품목표취급금액    26283 non-null  int64
#  9   상품목표주문금액    26283 non-null  int64
#  10  상품목표공헌이익금액  26283 non-null  int64
#  11  판매단가        26283 non-null  int64
#  12  수수료율        26283 non-null  float64
#  13  상품주문수량      26283 non-null  int64
#  14  상품주문금액      26283 non-null  int64
#  15  상품취소수량      26283 non-null  int64
#  16  상품취소금액      26283 non-null  int64
#  17  상품순주문수량     26283 non-null  int64
#  18  상품순주문금액     26283 non-null  int64
# ...

# %% [markdown]
# # 제작진 데이터

# %%
df2 = pd.read_csv('Crew_group.csv')
df2.head()
# Out:
#        방송Code  방송구분    프로그램명   PD   SH   TD      상품ID    MD담당자명     부서코드  \
# 0  1010036178  녹화방송    재방_의류  NaN  NaN  NaN  10242138       최승미  3111205
# 1  1019126356  녹화방송  재방_건강식품  NaN  NaN  NaN  10092003  심인혜,박만이건  3121405
# 2  1019226356  녹화방송  재방_건강식품  NaN  NaN  NaN  10092743  심인혜,박만이건  3121405
# 3  1040336520   재방송  재방_가공농산  NaN  NaN  NaN  10295865   최병규,최만훈  3121105
# 4  1021427468   재방송  재방_신선수산  NaN  NaN  NaN  10113666       신대혁  3121305
#
#     부서명   협력사ID        협력사명
# 0  생활2팀  104532    (주)턱케이앤코
# 1  식품4팀  100002     산협경제지주㈜
# 2  식품4팀  100002     산협경제지주㈜
# 3  식품1팀  104640   (주)하일에프앤씨
# 4  식품3팀  100004  물산업협동조합중앙회

# %%
df_2list = list(df2.columns)
df_2list
# Out:
# ['방송Code',
#  '방송구분',
#  '프로그램명',
#  'PD',
#  'SH',
#  'TD',
#  '상품ID',
#  'MD담당자명',
#  '부서코드',
#  '부서명',
#  '협력사ID',
#  '협력사명']

# %% [markdown]
# ### 홍보상품 데이터

# %%
df3 = pd.read_csv('Product.csv')
df3.head()
# Out:
#        상품ID                         상품명  브랜드ID        브랜드명 매입과세구분 대분류   중분류  \
# 0  10010984               완도 생매생이 35팩_3  21572    매생이(청삼대)     면세  식품   수산물
# 1  10011287           제조상궁 국내산 메주 담금 세트  21602  제조상궁메주담금세트     면세  식품   농산물
# 2  10011746         프리미엄 제주은갈치300gx6미_2  21481   은갈치(제주SF)     면세  식품   수산물
# 3  10012135             가포 멀티5 마사지기 풀세트  21264       가포멀티5     과세  건강  의료기기
# 4  10013259  맷돌로갈아만든검은콩두유(185ml×105팩)_3  20852        맷돌두유     과세  식품  가공식품
#
#     소분류       세분류   카테고리   협력사ID        협력사명  매입형태   배송방식    판매단가
# 0   건어물  김/미역/다시마   신선수산  100067    주식회사 뮤도파  위탁매입  협력사배송   40900
# 1    기타        기타   신선농산  100002     산협경제지주㈜  위탁매입    직택배   69900
# 2  일반어류        갈치   신선수산  100004  물산업협동조합중앙회  위탁매입    직택배   68900
# 3  의료용픔   공기압마사지기  레포츠기기  101032      (주)규포넷  위탁매입  협력사배송  198000
# 4   유제품        두유   가공농산  100875   (주)마나스코리아  위탁매입  협력사배송   59900

# %%
df3_lsit = list(df3.columns)

# %%
coulmn_list = df1_list + df_2list

# %%
len(coulmn_list )
# Out:
# 38

# %%
result = []
for i in coulmn_list:
    if i not in result:
        result.append(i)

result
# Out:
# ['방송Code',
#  '소요분',
#  '가중분',
#  '방송구분',
#  '프로그램명',
#  '상품ID',
#  '상품명',
#  '매입과세구분',
#  '상품목표취급금액',
#  '상품목표주문금액',
#  '상품목표공헌이익금액',
#  '판매단가',
#  '수수료율',
#  '상품주문수량',
#  '상품주문금액',
#  '상품취소수량',
#  '상품취소금액',
#  '상품순주문수량',
#  '상품순주문금액',
#  '상품예상취급금액',
#  'ARS금액',
#  '매입형태',
#  '배송방식',
#  '상품방송순번',
#  '방송시작시간',
#  '방송종료시간',
#  'PD',
#  'SH',
#  'TD',
#  'MD담당자명',
#  '부서코드',
#  '부서명',
#  '협력사ID',
#  '협력사명']

# %%
len(result)
# Out:
# 34

# %%
coulmn_list
# Out:
# ['방송Code',
#  '소요분',
#  '가중분',
#  '방송구분',
#  '프로그램명',
#  '상품ID',
#  '상품명',
#  '매입과세구분',
#  '상품목표취급금액',
#  '상품목표주문금액',
#  '상품목표공헌이익금액',
#  '판매단가',
#  '수수료율',
#  '상품주문수량',
#  '상품주문금액',
#  '상품취소수량',
#  '상품취소금액',
#  '상품순주문수량',
#  '상품순주문금액',
#  '상품예상취급금액',
#  'ARS금액',
#  '매입형태',
#  '배송방식',
#  '상품방송순번',
#  '방송시작시간',
#  '방송종료시간',
#  '방송Code',
#  '방송구분',
#  '프로그램명',
#  'PD',
#  'SH',
#  'TD',
#  '상품ID',
#  'MD담당자명',
#  '부서코드',
#  '부서명',
#  '협력사ID',
#  '협력사명']

# %%
result
# Out:
# ['방송Code',
#  '소요분',
#  '가중분',
#  '방송구분',
#  '프로그램명',
#  '상품ID',
#  '상품명',
#  '매입과세구분',
#  '상품목표취급금액',
#  '상품목표주문금액',
#  '상품목표공헌이익금액',
#  '판매단가',
#  '수수료율',
#  '상품주문수량',
#  '상품주문금액',
#  '상품취소수량',
#  '상품취소금액',
#  '상품순주문수량',
#  '상품순주문금액',
#  '상품예상취급금액',
#  'ARS금액',
#  '매입형태',
#  '배송방식',
#  '상품방송순번',
#  '방송시작시간',
#  '방송종료시간',
#  'PD',
#  'SH',
#  'TD',
#  'MD담당자명',
#  '부서코드',
#  '부서명',
#  '협력사ID',
#  '협력사명']

# %%
df4= pd.concat([df1, df2], join='outer', axis=1) # default
df4
# Out:
#              방송Code   소요분   가중분  방송구분    프로그램명      상품ID  \
# 0      1.010036e+09  50.0  52.7  녹화방송    재방_의류  10242138
# 1      1.019126e+09  60.0  38.1  녹화방송  재방_건강식품  10092003
# 2      1.019226e+09  60.0  38.1  녹화방송  재방_건강식품  10092743
# 3      1.040337e+09  60.0  19.7   재방송  재방_가공농산  10295865
# 4      1.021427e+09  60.0  16.1   재방송  재방_신선수산  10113666
# ...             ...   ...   ...   ...      ...       ...
# 26278  1.046263e+13  60.0  94.3   생방송       가전  11179512
# 26279  1.046263e+13  60.0  94.3   생방송       가전  11179514
# 26280  1.046263e+13  60.0  94.3   생방송       가전  11179504
# 26281  1.020263e+13  60.0  91.6   재방송  재방_건강식품  11152474
# 26282  1.042263e+13  74.8  66.7   생방송     가공수산  10605593
#
#                                 상품명 매입과세구분   상품목표취급금액   상품목표주문금액  ...  \
# 0           [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트     과세   65645345  117223831  ...
# 1      [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2     과세   23774849   29178755  ...
# ...

# %%
df4
# Out:
#              방송Code   소요분   가중분  방송구분    프로그램명      상품ID  \
# 0      1.010036e+09  50.0  52.7  녹화방송    재방_의류  10242138
# 1      1.019126e+09  60.0  38.1  녹화방송  재방_건강식품  10092003
# 2      1.019226e+09  60.0  38.1  녹화방송  재방_건강식품  10092743
# 3      1.040337e+09  60.0  19.7   재방송  재방_가공농산  10295865
# 4      1.021427e+09  60.0  16.1   재방송  재방_신선수산  10113666
# ...             ...   ...   ...   ...      ...       ...
# 26278  1.046263e+13  60.0  94.3   생방송       가전  11179512
# 26279  1.046263e+13  60.0  94.3   생방송       가전  11179514
# 26280  1.046263e+13  60.0  94.3   생방송       가전  11179504
# 26281  1.020263e+13  60.0  91.6   재방송  재방_건강식품  11152474
# 26282  1.042263e+13  74.8  66.7   생방송     가공수산  10605593
#
#                                 상품명 매입과세구분   상품목표취급금액   상품목표주문금액  ...  \
# 0           [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트     과세   65645345  117223831  ...
# 1      [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2     과세   23774849   29178755  ...
# ...

# %%
df4.columns
# Out:
# Index(['방송Code', '소요분', '가중분', '방송구분', '프로그램명', '상품ID', '상품명', '매입과세구분',
#        '상품목표취급금액', '상품목표주문금액', '상품목표공헌이익금액', '판매단가', '수수료율', '상품주문수량',
#        '상품주문금액', '상품취소수량', '상품취소금액', '상품순주문수량', '상품순주문금액', '상품예상취급금액', 'ARS금액',
#        '매입형태', '배송방식', '상품방송순번', '방송시작시간', '방송종료시간', '방송Code', '방송구분', '프로그램명',
#        'PD', 'SH', 'TD', '상품ID', 'MD담당자명', '부서코드', '부서명', '협력사ID', '협력사명'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['방송Code', '방송구분', '프로그램명', 'PD', 'SH', 'TD', '상품ID', 'MD담당자명', '부서코드',
#        '부서명', '협력사ID', '협력사명'],
#       dtype='object')

# %%
df_fin = pd.merge(df1, df2)

# %%
df4 = pd.merge(df1, df2)

# %%
df4
# Out:
#            방송Code   소요분   가중분  방송구분    프로그램명      상품ID  \
# 0    1.010036e+09  50.0  52.7  녹화방송    재방_의류  10242138
# 1    1.019126e+09  60.0  38.1  녹화방송  재방_건강식품  10092003
# 2    1.019226e+09  60.0  38.1  녹화방송  재방_건강식품  10092743
# 3    1.040337e+09  60.0  19.7   재방송  재방_가공농산  10295865
# 4    1.021427e+09  60.0  16.1   재방송  재방_신선수산  10113666
# ..            ...   ...   ...   ...      ...       ...
# 995  1.016995e+11  75.0  25.2   재방송   재방_이미용  10242206
# 996  1.016996e+11  75.0  25.2   재방송   재방_이미용  10242207
# 997  1.016997e+11  75.0  25.2   재방송   재방_이미용  10242461
# 998  1.045998e+11  59.9  57.6   생방송       가전  10412077
# 999  1.006999e+11  60.1  59.2   생방송     F_침구  10423667
#
#                                  상품명 매입과세구분  상품목표취급금액   상품목표주문금액  ...  \
# 0            [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트     과세  65645345  117223831  ...
# 1       [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2     과세  23774849   29178755  ...
# 2        [단품_한삼인] 순홍삼진(50ml*30포)*1박스     과세  23774849   29178755  ...
# ...

# %%
df4
# Out:
#            방송Code   소요분   가중분  방송구분    프로그램명      상품ID  \
# 0    1.010036e+09  50.0  52.7  녹화방송    재방_의류  10242138
# 1    1.019126e+09  60.0  38.1  녹화방송  재방_건강식품  10092003
# 2    1.019226e+09  60.0  38.1  녹화방송  재방_건강식품  10092743
# 3    1.040337e+09  60.0  19.7   재방송  재방_가공농산  10295865
# 4    1.021427e+09  60.0  16.1   재방송  재방_신선수산  10113666
# ..            ...   ...   ...   ...      ...       ...
# 995  1.016995e+11  75.0  25.2   재방송   재방_이미용  10242206
# 996  1.016996e+11  75.0  25.2   재방송   재방_이미용  10242207
# 997  1.016997e+11  75.0  25.2   재방송   재방_이미용  10242461
# 998  1.045998e+11  59.9  57.6   생방송       가전  10412077
# 999  1.006999e+11  60.1  59.2   생방송     F_침구  10423667
#
#                                  상품명 매입과세구분  상품목표취급금액   상품목표주문금액  ...  \
# 0            [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트     과세  65645345  117223831  ...
# 1       [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2     과세  23774849   29178755  ...
# 2        [단품_한삼인] 순홍삼진(50ml*30포)*1박스     과세  23774849   29178755  ...
# ...

# %%
df4
# Out:
#            방송Code   소요분   가중분  방송구분    프로그램명      상품ID  \
# 0    1.010036e+09  50.0  52.7  녹화방송    재방_의류  10242138
# 1    1.019126e+09  60.0  38.1  녹화방송  재방_건강식품  10092003
# 2    1.019226e+09  60.0  38.1  녹화방송  재방_건강식품  10092743
# 3    1.040337e+09  60.0  19.7   재방송  재방_가공농산  10295865
# 4    1.021427e+09  60.0  16.1   재방송  재방_신선수산  10113666
# ..            ...   ...   ...   ...      ...       ...
# 995  1.016995e+11  75.0  25.2   재방송   재방_이미용  10242206
# 996  1.016996e+11  75.0  25.2   재방송   재방_이미용  10242207
# 997  1.016997e+11  75.0  25.2   재방송   재방_이미용  10242461
# 998  1.045998e+11  59.9  57.6   생방송       가전  10412077
# 999  1.006999e+11  60.1  59.2   생방송     F_침구  10423667
#
#                                  상품명 매입과세구분  상품목표취급금액   상품목표주문금액  ...  \
# 0            [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트     과세  65645345  117223831  ...
# 1       [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2     과세  23774849   29178755  ...
# 2        [단품_한삼인] 순홍삼진(50ml*30포)*1박스     과세  23774849   29178755  ...
# ...

# %%
df3
# Out:
#           상품ID                         상품명  브랜드ID          브랜드명 매입과세구분   대분류  \
# 0     10010984               완도 생매생이 35팩_3  21572      매생이(청삼대)     면세    식품
# 1     10011287           제조상궁 국내산 메주 담금 세트  21602    제조상궁메주담금세트     면세    식품
# 2     10011746         프리미엄 제주은갈치300gx6미_2  21481     은갈치(제주SF)     면세    식품
# 3     10012135             가포 멀티5 마사지기 풀세트  21264         가포멀티5     과세    건강
# 4     10013259  맷돌로갈아만든검은콩두유(185ml×105팩)_3  20852          맷돌두유     과세    식품
# ...        ...                         ...    ...           ...    ...   ...
# 6811  11179512     ■연말특가■제우스커브드 UHD TV 65형  42184  제우스커브드TV2019     과세    가전
# 6812  11179513         [데이스포] 밀크패드 1세트100p  44635      데이스포배변패드     과세  생활용품
# 6813  11179514         2021 제우스 UHD TV 75형  42174     제우스TV2019     과세    가전
# 6814  11179873        (직택배)[단품]100% 한우사골_3  44508          한우사골     면세    식품
# 6815  11180912   [농협고구마]해남 황토 꿀고구마 10kg_화산  36303   농협고구마(농협식품)     면세    식품
#
# ...

# %%
df2
# Out:
#                방송Code  방송구분    프로그램명   PD       SH   TD      상품ID    MD담당자명  \
# 0          1010036178  녹화방송    재방_의류  NaN      NaN  NaN  10242138       최승미
# 1          1019126356  녹화방송  재방_건강식품  NaN      NaN  NaN  10092003  심인혜,박만이건
# 2          1019226356  녹화방송  재방_건강식품  NaN      NaN  NaN  10092743  심인혜,박만이건
# 3          1040336520   재방송  재방_가공농산  NaN      NaN  NaN  10295865   최병규,최만훈
# 4          1021427468   재방송  재방_신선수산  NaN      NaN  NaN  10113666       신대혁
# ...               ...   ...      ...  ...      ...  ...       ...       ...
# 26278  10462627842184   생방송       가전  가관석   최석,신유이  유숙하  11179512   가길호,남주혜
# 26279  10462627942174   생방송       가전  가관석   최석,신유이  유숙하  11179514   가길호,남주혜
# 26280  10462628042184   생방송       가전  가관석   최석,신유이  유숙하  11179504   가길호,남주혜
# 26281  10202628144834   재방송  재방_건강식품  NaN      NaN  NaN  11152474       심인혜
# 26282  10422628241399   생방송     가공수산  최상열  최규좌,최은경  유숙하  10605593       최희수
#
#           부서코드   부서명   협력사ID          협력사명
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   방송Code      1000 non-null   float64
#  1   소요분         1000 non-null   float64
#  2   가중분         1000 non-null   float64
#  3   방송구분        1000 non-null   object
#  4   프로그램명       1000 non-null   object
#  5   상품ID        1000 non-null   int64
#  6   상품명         1000 non-null   object
#  7   매입과세구분      1000 non-null   object
#  8   상품목표취급금액    1000 non-null   int64
#  9   상품목표주문금액    1000 non-null   int64
#  10  상품목표공헌이익금액  1000 non-null   int64
#  11  판매단가        1000 non-null   int64
#  12  수수료율        1000 non-null   float64
#  13  상품주문수량      1000 non-null   int64
#  14  상품주문금액      1000 non-null   int64
#  15  상품취소수량      1000 non-null   int64
#  16  상품취소금액      1000 non-null   int64
#  17  상품순주문수량     1000 non-null   int64
#  18  상품순주문금액     1000 non-null   int64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6816 entries, 0 to 6815
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상품ID    6816 non-null   int64
#  1   상품명     6816 non-null   object
#  2   브랜드ID   6816 non-null   int64
#  3   브랜드명    6816 non-null   object
#  4   매입과세구분  6816 non-null   object
#  5   대분류     6816 non-null   object
#  6   중분류     6816 non-null   object
#  7   소분류     6816 non-null   object
#  8   세분류     6816 non-null   object
#  9   카테고리    6816 non-null   object
#  10  협력사ID   6816 non-null   int64
#  11  협력사명    6816 non-null   object
#  12  매입형태    6816 non-null   object
#  13  배송방식    6816 non-null   object
#  14  판매단가    6816 non-null   int64
# dtypes: int64(4), object(11)
# memory usage: 798.9+ KB

# %%
df = pd.read_csv('df.csv', encoding= 'euc-kr')
df.head()
# Out:
#        방송Code   소요분   가중분  방송구분 프로그램명      상품ID                           상품명  \
# 0  1010036178  50.0  52.7  녹화방송    의류  10242138       [비지트인뉴욕콜렉션] 퓨어 캐시미어 롱코트
# 1  1019126356  60.0  38.1  녹화방송  건강식품  10092003  [한삼인]순홍삼진(50ml*30포)*7박스+쇼7_2
# 2  1019226356  60.0  38.1  녹화방송  건강식품  10092743   [단품_한삼인] 순홍삼진(50ml*30포)*1박스
# 3  1040336520  60.0  19.7   재방송  가공농산  10295865                 이상용의 우리밀 크레마롤
# 4  1021427468  60.0  16.1   재방송  신선수산  10113666         국내산 자숙 문어슬라이스 120g*9팩
#
#   매입과세구분  상품목표취급금액   상품목표주문금액  ...   세분류  카테고리   요일  분기  주  월  시작시간    연도  계절  \
# 0     과세  65645345  117223831  ...    기타    의류  금요일   1  1  1     0  2020  겨울
# 1     과세  23774849   29178755  ...  건강즙류  건강식품  금요일   1  1  1     1  2020  겨울
# 2     과세  23774849   29178755  ...  건강즙류  건강식품  금요일   1  1  1     1  2020  겨울
# 3     과세  24568911   28904601  ...   빵/쨈  가공농산  금요일   1  1  1     2  2020  겨울
# 4     면세  20131383   24550467  ...    문어  신선수산  금요일   1  1  1     3  2020  겨울
#
#      PSHOP매출액
# ...

# %%
df.columns
# Out:
# Index(['방송Code', '소요분', '가중분', '방송구분', '프로그램명', '상품ID', '상품명', '매입과세구분',
#        '상품목표취급금액', '상품목표주문금액', '상품목표공헌이익금액', '판매단가', '수수료율', '상품주문수량',
#        '상품주문금액', '상품취소수량', '상품취소금액', '상품순주문수량', '상품순주문금액', '상품예상취급금액', 'ARS금액',
#        '매입형태', '배송방식', '상품방송순번', '방송시작시간', '방송종료시간', 'PD', 'SH', 'TD',
#        'MD담당자명', '부서코드', '부서명', '협력사ID', '협력사명', '브랜드ID', '브랜드명', '대분류', '중분류',
#        '소분류', '세분류', '카테고리', '요일', '분기', '주', '월', '시작시간', '연도', '계절',
#        'PSHOP매출액'],
#       dtype='object')

# %%
df.시작시간
# Out:
# 0         0
# 1         1
# 2         1
# 3         2
# 4         3
#          ..
# 25651    21
# 25652    21
# 25653    21
# 25654    22
# 25655    23
# Name: 시작시간, Length: 25656, dtype: int64
